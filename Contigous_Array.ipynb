# %% [markdown]
# https://algo.monster/liteproblems/525
#
# Given a binary array nums, return the maximum length of a contiguous subarray with an equal number of 0 and 1.
#
# Example 1:
#
# Input: nums = [0,1]
# Output: 2
# Explanation: [0, 1] is the longest contiguous subarray with an equal number of 0 and 1.
#
#
# Example 2:
#
# Input: nums = [0,1,0]
# Output: 2
# Explanation: [0, 1] (or [1, 0]) is a longest contiguous subarray with equal number of 0 and 1.
#
# Example 3:
#
# Input: nums = [0,1,1,1,1,1,0,0,0]
# Output: 6
# Explanation: [1,1,1,0,0,0] is the longest contiguous subarray with equal number of 0 and 1.

# %%
    def findMaxLength(nums):

        # HashMap to store the first occurrence index of each cumulative sum

        # Initialize with sum 0 at index -1 (before array starts)

        sum_to_index = {0: -1}
        
        # Track maximum length and running cumulative sum

        max_length = 0

        cumulative_sum = 0

        # Iterate through the array with index and value

        for index, value in enumerate(nums):

            # Treat 1 as +1 and 0 as -1 for cumulative sum
            # This way, equal numbers of 0s and 1s will have sum = 0

            cumulative_sum += 1 if value == 1 else -1

            # If we've seen this sum before, we found a subarray with equal 0s and 1s

            if cumulative_sum in sum_to_index:

                # Calculate length from first occurrence to current index
                current_length = index - sum_to_index[cumulative_sum]
                max_length = max(max_length, current_length)
            else:
                # First time seeing this sum, record its index
                sum_to_index[cumulative_sum] = index

        return max_length

# %%
nums = [0,1,1,1,1,1,0,0,0]
findMaxLength(nums)
# Out:
# 6

# %% [markdown]
# 🎯 In ONE sentence
#
# If sum is seen again → equal 0s and 1s between the two positions.
#
#
# If sum is new → store it, so we can detect such a subarray later.

# %% [markdown]
# In this context, **“seen before” means that the cumulative sum has already appeared earlier in the array**.
#
# ---
#
# # ✅ What does “seen before” really mean?
#
# Inside the loop, you keep a dictionary:
#
# ```python
# sum_to_index = {0: -1}
# ```
#
# As you move through the array, you compute a **cumulative sum**.
#
# If the cumulative sum appears again later:
#
# 👉 **That exact same sum happened previously.**
#
# So the dictionary already contains that cumulative sum →
# we say it is **“seen before”**.
#
# ---
#
# # ✔ Why does it matter?
#
# If the same cumulative sum appears twice:
#
# ### Example:
#
# Index 2: cumulative sum = 1
# Index 7: cumulative sum = 1  ← **seen before**
#
# This means:
#
# 📌 **Between index 3 and 7, the net sum is zero → equal number of 0s and 1s.**
#
# Because:
#
# ```
# (sum at index 7) – (sum at index 2) = 0
# ```
#
# That is why “seen before” is important.
#
# ---
#
# # 📘 Simple Example
#
# nums = [0,1,0,1]
#
# Convert 0 → -1, 1 → +1
#
# | Index | Value | Cumulative Sum                             |
# | ----- | ----- | ------------------------------------------ |
# | 0     | 0     | -1  ← new → store                          |
# | 1     | 1     | 0   ← seen before (sum_to_index has 0: -1) |
# | 2     | 0     | -1  ← seen before (we saw -1 at index 0)   |
# | 3     | 1     | 0   ← seen before again                    |
#
# Whenever the sum appears again → **seen before**.
#
# ---
#
# # 💡 In one simple line:
#
# 👉 **“Seen before” = this cumulative sum was already recorded earlier in the dictionary.**
#
# ---
#
# If you want, I can show a visual diagram of how this works step-by-step.

# %% [markdown]
# | index | value | cumulative_sum | sum_to_index | Action                     |
# | ----- | ----- | -------------- | ------------ | -------------------------- |
# | -1    | —     | 0              | {0: -1}      | Start                      |
# | 0     | 0     | -1             | store -1     | first time → store index 0 |
# | 1     | 1     | 0              | seen before  | subarray = 1 - (-1) = 2    |

# %% [markdown]
# Great question — this is the part that confuses most people.
# Let’s explain it **clearly and simply**.
#
# ---
#
# # ✅ **What does `sum_to_index = {0: -1}` mean?**
#
# This dictionary means:
#
# 👉 **Cumulative sum 0 occurred at index –1.**
#
# But index **–1 is not a real index in the array**.
# We use it as a **starting point before the array begins**.
#
# ---
#
# # ✔ Why do we do this?
#
# It allows us to correctly detect subarrays that start from index **0**.
#
# Example:
#
# ```
# nums = [0,1]
# ```
#
# After converting:
#
# ```
# 0 → -1
# 1 → +1
# ```
#
# Cumulative sum at index 1 becomes:
#
# ```
# -1 + 1 = 0
# ```
#
# If we had NOT initialized `{0: -1}`, we would miss the fact that:
#
# 👉 cumulative_sum became **0 at index 1**
# 👉 meaning the entire subarray **from index 0 to 1** has equal 0s and 1s
#
# Because:
#
# ```
# current_index - (-1) = 1 - (-1) = 2
# ```
#
# Which is the correct length.
#
# ---
#
# # 🎯 **In one simple sentence**
#
# `{0: -1}` means:
#
# > Before the array starts, the cumulative sum is 0.
#
# This allows the algorithm to correctly identify subarrays starting from index 0.
#
# ---
#
# # 📘 Mini Example
#
# nums = [0,1]
#
# Steps:
#
# | Index | Value | Cumulative Sum | sum_to_index | Meaning    |
# | ----- | ----- | -------------- | ------------ | ---------- |
# | -1    | —     | 0              | {0: -1}      | initial    |
# | 0     | 0     | -1             | store -1     | first time |
# | 1     | 1     | 0              | seen before! | use -1     |
#
# Length:
#
# ```
# 1 - (-1) = 2  → correct answer
# ```
#
# ---
