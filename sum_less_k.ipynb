# %%
def countPairs(nums, target):
    nums.sort()
    count = 0
    left =0
    right = len(nums) -1
        
    while left < right:
        sum = nums[left] + nums[right]
        if sum < target:
            count = count + 1
            continue
        elif sum >= target:
            right = right -1
        
    return count

# %%
nums = [-1,1,2,3,1]
nums.sort()
print(nums)
target = 2
# Out:
# [-1, 1, 1, 2, 3]

# %%
countPairs(nums, target)

# %%
def countPairs(nums, target):
    nums.sort()
    count = 0
    left =0
    right = len(nums) -1
        
    while left < right:
        sum = nums[left] + nums[right]
        if sum < target:
            count = count + 1
            return count
        elif sum >= target:
            right = right -1     
    return False

# %%
countPairs(nums, target)
# Out:
# 1

# %%
# Function to check whether any pair exists
# whose sum is less than the given target value
def two_sum(arr, target):
    # Sort the array
    arr.sort()
    print(arr)
    left, right = 0, len(arr) - 1
    count= 0
    result = []

    # Iterate while left pointer is less than right
    while left < right:
        sum = arr[left] + arr[right]
        # Check if the sum matches the target
        if sum < target:
            count += 1
            left += 1
            return count
        elif sum == target:
            left +=1
            right -= 1  
        else:
            right -= 1
    
    return 0

# %%
nums = [-1,1,2,3,1]
target = 2
two_sum(nums,target)
# Out:
# [-1, 1, 1, 2, 3]
# 1

# %%
arr = [-3,-3, 1, 1, 1, 4]
target = -2
two_sum(nums,target)
# Out:
# [-1, 1, 1, 2, 3]
# 0
