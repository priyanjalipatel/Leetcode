# %%
def isPalindrome(x):
    str_rev =  '' 
    index = len(x)
    while index>0:
        str_rev += x[index-1]
        index -=1
    if str_rev == x:
        return True
    else:
        return False

# %%
string = 'reve'
isPalindrome(string)
# Out:
# False

# %%
def isPalindrome(x):
    str_rev =  '' 
    s = str(x)
    index = len(s)
    while index>0:
        str_rev += s[index-1]
        index -=1
    if str_rev == s:
        return True
    else:
        return False

# %%
num = 1214
isPalindrome(num)
# Out:
# False

# %% [markdown]
# ## Valid Palindrome
#
# A phrase is a palindrome if, after converting all uppercase letters into lowercase letters and removing all non-alphanumeric characters, it reads the same forward and backward. Alphanumeric characters include letters and numbers.
#
# Given a string s, return true if it is a palindrome, or false otherwise.
#
#
#
# Example 1:
#
# Input: s = "A man, a plan, a canal: Panama"
# Output: true
# Explanation: "amanaplanacanalpanama" is a palindrome.

# %%
def isPalindrome(s):
    left, right = 0, len(s) - 1
    while left < right:
        if not s[left].isalnum():
            left += 1
        elif not s[right].isalnum():
            right -= 1
        elif s[left].lower() != s[right].lower():
            return False
        else:
            left += 1
            right -= 1
    return True

# %% [markdown]
# ---
#
# ## Example string
#
# ```python
# s = "A man, a plan, a canal: Panama"
# ```
#
# ### After ignoring:
#
# * spaces
# * commas
# * colon
# * case differences
#
# It should read the same forwards and backwards.
#
# ---
#
# ## Step 1️⃣ Initialize pointers
#
# ```python
# left = 0
# right = len(s) - 1
# ```
#
# ```
# Index:  0                         29
# String: A man, a plan, a canal: Panama
#         ^                         ^
#       left                      right
# ```
#
# ---
#
# ## Step 2️⃣ First comparison
#
# ### Characters:
#
# * `s[left] = 'A'`
# * `s[right] = 'a'`
#
# Both are:
#
# * alphanumeric ✔
# * `'A'.lower() == 'a'.lower()` ✔
#
# ✅ Match → move inward
#
# ```
# left = 1
# right = 28
# ```
#
# ---
#
# ## Step 3️⃣ Skip non-alphanumeric
#
# ### `s[left] = ' '` (space)
#
# * `isalnum()` ❌ → skip
#
# ```
# left = 2
# ```
#
# Now:
#
# * `s[left] = 'm'`
# * `s[right] = 'm'`
#
# ✅ Match → move inward
#
# ```
# left = 3
# right = 27
# ```
#
# ---
#
# ## Step 4️⃣ Skip again
#
# * `s[left] = 'a'` ✔
# * `s[right] = 'a'` ✔
#
# ✅ Match
#
# ```
# left = 4
# right = 26
# ```
#
# ---
#
# ## Step 5️⃣ Handle punctuation
#
# * `s[left] = 'n'` ✔
# * `s[right] = 'n'` ✔
#
# ✅ Match
#
# ```
# left = 5
# right = 25
# ```
#
# * `s[left] = ','` ❌ → skip
#
# ```
# left = 6
# ```
#
# * `s[left] = ' '` ❌ → skip
#
# ```
# left = 7
# ```
#
# ---
#
# ## Step 6️⃣ Continue comparisons
#
# Now comparing:
#
# * `'a'` ↔ `'a'`
# * `'p'` ↔ `'p'`
# * `'l'` ↔ `'l'`
# * `'a'` ↔ `'a'`
# * `'n'` ↔ `'n'`
# * …
#
# Each time:
#
# * punctuation/spaces skipped
# * letters matched
# * pointers move inward
#
# ---
#
# ## Step 7️⃣ Pointers meet
#
# Eventually:
#
# ```
# left >= right
# ```
#
# That means:
#
# * All meaningful characters matched
# * No mismatch found
#
# ---
#
# ## ✅ Final Result
#
# ```python
# return True
# ```
#
# The string **is a palindrome** 🎉
#
# ---
#
# ## 🔁 What would return False?
#
# Example:
#
# ```python
# s = "race a car"
# ```
#
# At some point:
#
# * `'e' != 'a'` ❌
#   → immediately return `False`
#
# ---
#
# ## 🧠 One-line intuition
#
# > Compare characters from both ends, skip junk, ignore case, stop if mismatch.
#
# ---

# %%
def isPalindrome(x):
    str_rev =  '' 
    s = str(x)
    index = len(s)
    while index>0:
        str_rev += s[index-1]
        index -=1
    if str_rev == s:
        return True
    else:
        return False
