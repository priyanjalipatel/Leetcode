# %%
def findMaxLength(nums):
        count = 0
        sum = 0
        for i, val in enumerate(nums):     
            if val == 0:
                val = -1
            sum  += val
            #print(sum)
            if sum in map:
                count += map[sum]
            map(val) == map.get(val, 0) + 1
        return count

# %%
nums = [0,1]

findMaxLength(nums)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 3
#       1 nums = [0,1]
# ----> 3 findMaxLength(nums)
#
# Cell In[47], line 9, in findMaxLength(nums)
#       7 sum  += val
#       8 #print(sum)
# ----> 9 if sum in map:
#      10     count += map[sum]
#      11 map(val) == map.get(val, 0) + 1
#
# TypeError: argument of type 'type' is not iterable
