# %% [markdown]
# 26. Remove Duplicates from Sorted Array
# Given an integer array nums sorted in non-decreasing order, remove the duplicates in-place such that each unique element appears only once. The relative order of the elements should be kept the same. Then return the number of unique elements in nums.
#
# Consider the number of unique elements of nums to be k, to get accepted, you need to do the following things:
#
#     Change the array nums such that the first k elements of nums contain the unique elements in the order they were present in nums initially. The remaining elements of nums are not important as well as the size of nums.
#     Return k.
#
#
#
# I/P: nums = [1,1,2,2,3]
# O/P: 2, nums = [1,2,3,_,_]

# %%
#nums = [1,1,2]
nums = [1,1,2,2,4]

# %% [markdown]
# for i, val1 in nums:
#     for i+1, val2 in nums:
#         print(val1)
#         print(val2)

# %%
for i in range(len(nums)):
    #print(i)
    for j in range((i+1),len(nums)):
        if (nums[i]==nums[j]):
            #print(nums[i])
            nums[j] = "_"
            print(nums[j])
        else:
            nums[j]
            print(nums[j])
# Out:
# _
# 2
# _
# 4
# 2
# _
# 4
# _
# 4
# 4

# %%
print(nums)
# Out:
# [1, '_', 2, '_', 4]

# %%
for i in range(len(nums)):
    #print(i)
    for j in range((i+1),len(nums)):
        if (nums[i]==nums[j]):
            #print(nums[i])
            nums[j] = "_"
            print(nums[j])
        else:
            nums[j]
            print(nums[j])
# Out:
# _
# 2
# 2
# 4
# 2
# 2
# 4
# _
# 4
# 4

# %%
#nums = [1,1,2]
nums = [1,1,2,2,4]

# %%
for i in range(len(nums)):
    #print(i)
    for j in range((i+1),len(nums)):
            #print(nums[i])
            if (nums[i]==nums[j]):
                    nums[i] = nums[j]
                    nums[j] = "_"
                    print(nums[j])
    
            else:
                    print(nums[j])
# Out:
# _
# 2
# 2
# 4
# 2
# 2
# 4
# _
# 4
# 4

# %%
print(nums)
# Out:
# [1, '_', 2, '_', 4]

# %%
import string
chars = "_"
non_special_elements = []
special_elements = []

# %%
for i in range(len(nums)):
    #print(i)
    for j in range((i+1),len(nums)):
            #print(nums[i])
            if (nums[i]==nums[j]):
                    nums[i] = nums[j]
                    nums[j] = "_"
                    print(nums[j])
    
            else:
                    print(nums[j])
# Out:
# _
# 2
# _
# 4
# 2
# _
# 4
# _
# 4
# 4

# %%
for item in nums:
    if isinstance(item, str) and item in special_chars:
        special_elements.append(item)
    else:
        non_special_elements.append(item)

# %%
new_list = non_special_elements + special_elements
print(new_list)
print(len(non_special_elements))
length = len(non_special_elements)
# Out:
# [1, 2, 4, '_', '_']
# 3

# %%
print(length, "," , new_list)
# Out:
# 3 , [1, 2, 4, '_', '_']

# %%
   def removeDuplicates(nums):
        """
        :type nums: List[int]
        :rtype: int
        """
        if not nums:
            return 0

        i = 0  # last unique index
        for j in range(1, len(nums)):
            if nums[j] != nums[i]:
                i += 1
                nums[i] = nums[j]

        print(nums[:])

# %%
list = [1,1,2,2,4]
removeDuplicates(list)
# Out:
# [1, 2, 4, 2, 4]

# %%
# remove_duplicates.py

class Solution(object):
    def removeDuplicates(self, nums):
        """
        :type nums: List[int]
        :rtype: int
        """
        if not nums:
            return 0

        i = 0  # pointer for last unique element
        for j in range(1, len(nums)):
            if nums[j] != nums[i]:
                i += 1
                nums[i] = nums[j]

        return i + 1


if __name__ == "__main__":
    nums = [0,0,1,1,1,2,2,3,3,4]
    solution = Solution()
    k = solution.removeDuplicates(nums)

    print("k (unique count):", k)
    print("nums after removeDuplicates:", nums[:k])
# Out:
# k (unique count): 5
# nums after removeDuplicates: [0, 1, 2, 3, 4]
