# %% [markdown]
# You are given two non-empty linked lists representing two non-negative integers. The digits are stored in reverse order, and each of their nodes contains a single digit. Add the two numbers and return the sum as a linked list.
#
# You may assume the two numbers do not contain any leading zero, except the number 0 itself.
#
# https://www.geeksforgeeks.org/python/python-reversing-list/

# %% [markdown]
# Input: l1 = [2,4,3], l2 = [5,6,4]
# Output: [7,0,8]
# Explanation: 342 + 465 = 807.
# #solution : https://leetcode.com/problems/add-two-numbers/solutions/7170873/easy-python-solution-o-max-m-n-time-o-max-m-n-space-convert-add-approach/

# %%
import numpy as np

# %%
l1 = [2,4,3]
l2 = [5,6,4]

# %%
for i in range(len(l1)):
    item1 = (10**i)*l1[i] + (10**(i+1)) * l1[i+1] + (10**(i+2)) * l1[i+2]
    #item2 = int(l2_rev[i])
    print(item1)
    #print(np.sum(item1 + item2))

# %%
l1 = [2,4,3]

# %%
for i, val in enumerate(l1):
    #print((10**i)*val)
    #print((10**(i+1)) * (val))
    #item1 = (val + 10 * (val+1) + 100 * (val+2))
    #print(item1)
    for j, val1 in enumerate(l2):
        print(

# %%
l1 = [2,4,3]
number1 = l1[0] + 10*l1[1] + 100 *l1[2]
print(number1)
# Out:
# 342

# %%
l2 = [5,6,4]
number2 = l2[0] + 10*l2[1] + 100 *l2[2]
print(number2)
# Out:
# 465

# %%
print(number1 + number2)
# Out:
# 807

# %%
def addTwoNumbers(l1, l2):
        """
        :type l1: Optional[ListNode]
        :type l2: Optional[ListNode]
        :rtype: Optional[ListNode]
        """
        n1=0 #we3'll store the first number
        c=l1 #assigning the current list's head
        i=0 #we'll need this as power of 10
        while c: #traversing the full list
            t=c.val*(10**i) #value to add for this digit in list
            n1+=t #adding to the number
            i+=1 #increasing the power of 10
            c=c.next #incrementing the node
        n2=0 #DOING THE SAME PROCESS FOR SECOND NUMBER
        c=l2
        i=0
        while c:
            t=c.val*(10**i)
            n2+=t
            i+=1
            c=c.next
        s=n1+n2 #GETTING THE SUM OF TWO NUMBERS
        if s == 0: #WHEN SUM IS 0, RETURN A LINKED LIST WITH A SINGLE 0 NODE
            return ListNode(0)
        d=ListNode(0) #MAKING A NEW LIST FOR THE SUM
        c=d #D Is our dummy node you'll see why!
        while s>0: #till the number isn't 0
            v=s%10 #take the last digit
            s//=10 #remove the last digit now
            c.next=ListNode(v) #store the last digit as list node
            c=c.next #increment the list
        head=d.next #HEAD OF LIST WILL BE NEXT OF DUMMY,AS DUMMY WAS 0,THE DIGIT START AFTER IT
        return head #returning the list!

# %%
addTwoNumbers(l1, l2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 addTwoNumbers(l1, l2)
#
# Cell In[6], line 11, in addTwoNumbers(l1, l2)
#       9 i=0 #we'll need this as power of 10
#      10 while c: #traversing the full list
# ---> 11     t=c.val*(10**i) #value to add for this digit in list
#      12     n1+=t #adding to the number
#      13     i+=1 #increasing the power of 10
#
# AttributeError: 'list' object has no attribute 'val'
