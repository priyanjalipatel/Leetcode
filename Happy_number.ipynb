# %% [markdown]
# Write an algorithm to determine if a number n is happy.
#
# A happy number is a number defined by the following process:
#
#     Starting with any positive integer, replace the number by the sum of the squares of its digits.
#     Repeat the process until the number equals 1 (where it will stay), or it loops endlessly in a cycle which does not include 1.
#     Those numbers for which this process ends in 1 are happy.
#
# Return true if n is a happy number, and false if not.
#
# Example 1:
#
# Input: n = 19
#
# Output: true
#
# Explanation:
#
# 1^2 + 9^2 = 82
# 8^2 + 2^2 = 68
# 6^2 + 8^2 = 100
# 1^2 + 0^2 + 0^2 = 1
#
# Example 2:
#
# Input: n = 2
# Output: false

# %% [markdown]
# while n != 1 and n not in seen:
#
# Where:
#
#     n != 1 → stop if we reach happiness
#
#     n not in seen → stop if we enter a cycle

# %%
def isHappy(n):
    total = 0
    seen = set()
    while n != 1:
         num = str(n)
         # Iterate through the string, converting each character back to an integer
         qr_digit = [int(digit)**2 for digit in num] 
         #print(qr_digit)
         #sqr_digit = digits[i]**2
         total = sum(qr_digit)
         seen.add(n)
         if total == 1:
            return True
         n = total
    return False

# %%
isHappy(19)
# Out:
# True
