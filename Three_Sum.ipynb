# %% [markdown]
# Given an integer array nums, return all the triplets [nums[i], nums[j], nums[k]] such that i != j, i != k, and j != k, and nums[i] + nums[j] + nums[k] == 0.
#
# Notice that the solution set must not contain duplicate triplets.
#
#
#
# Example 1:
#
# Input: nums = [-1,0,1,2,-1,-4]
# Output: [[-1,-1,2],[-1,0,1]]
# Explanation:
# nums[0] + nums[1] + nums[2] = (-1) + 0 + 1 = 0.
# nums[1] + nums[2] + nums[4] = 0 + 1 + (-1) = 0.
# nums[0] + nums[3] + nums[4] = (-1) + 2 + (-1) = 0.
# The distinct triplets are [-1,0,1] and [-1,-1,2].
# Notice that the order of the output and the order of the triplets does not matter.
#
# Example 2:
#
# Input: nums = [0,1,1]
# Output: []
# Explanation: The only possible triplet does not sum up to 0.
#
# Example 3:
#
# Input: nums = [0,0,0]
# Output: [[0,0,0]]
# Explanation: The only possible triplet sums up to 0.
#
#
#
# Constraints:
#
#     3 <= nums.length <= 3000
#     -105 <= nums[i] <= 105

# %%
nums = [-1,0,1,2,-1,-4]
target = 0

# %% [markdown]
# for i in range(len(nums)):
#     #print(i)
#     for j in range((i+1),len(nums)):
#         for k in range((i+2), len(nums)):
#             if (nums[i]+nums[j]+nums[k])==target:
#                 #print(i,j,k)
#                 list = [nums[i], nums[j], nums[k]]
#                 print(list)
#                 #if sorted(list1) == sorted(list2):

# %% [markdown]
# ### ⚠️ This is O(n³) and will time out for large inputs in LeetCode, but works fine for small cases.

# %%
class Solution(object):
    def threeSum(self, nums):
        """
        :type nums: List[int]
        :rtype: List[List[int]]
        """
        res = []
        nums.sort()  # sort to help with duplicates

        for i in range(len(nums)):
            for j in range(i + 1, len(nums)):
                for k in range(j + 1, len(nums)):
                    if nums[i] + nums[j] + nums[k] == 0:
                        triplet = [nums[i], nums[j], nums[k]]
                        if triplet not in res:  # avoid duplicates
                            res.append(triplet)

        return res

# %% [markdown]
# ## ✅ Efficient Solution (O(n²))

# %%
class Solution(object):
    def threeSum(self, nums):
        """
        :type nums: List[int]
        :rtype: List[List[int]]
        """
        nums.sort()
        res = []

        for i in range(len(nums)-2):
            
            # Skip duplicates for i
            if i > 0 and nums[i] == nums[i - 1]:
                continue
                
            left, right = i + 1, len(nums) - 1
            
            while left < right:
                total = nums[i] + nums[left] + nums[right]
                if total == 0:
                    res.append([nums[i], nums[left], nums[right]])
                    # Skip duplicates for left and right
                    while left < right and nums[left] == nums[left + 1]:
                        left += 1
                    while left < right and nums[right] == nums[right - 1]:
                        right -= 1
                    left += 1
                    right -= 1
                elif total < 0:
                    left += 1
                else:
                    right -= 1

        return res

# %% [markdown]
# Why this works
#
# Sort array first.
#
# Fix one number (i).
#
# Use two pointers (left, right) to find pairs that sum to -nums[i].
#
# Skip duplicates to avoid repeated triplets.
#
# Collect all results in res, return at the end.

# %% [markdown]
# ```python
# for i in range(len(nums) - 2):
# ```
#
# ---
#
# # ✅ **Why `len(nums) - 2`?**
#
# Because for a **3-sum**, you need **three numbers**:
#
# * one from index **i**
# * one from index **left**
# * one from index **right**
#
# So:
#
# * `i` must stop **at the third-last position**
# * otherwise you won’t have space for `left` and `right`
#
# ---
#
# ## 🔍 Example
#
# Let the array length = 6
# Valid `i` positions:
#
# ```
# i = 0 → left=1, right=5  (OK)
# i = 1 → left=2, right=5  (OK)
# i = 2 → left=3, right=5  (OK)
# i = 3 → left=4, right=5  (OK)
# i = 4 → left=5, right=5  (NOT valid: left == right)
# i = 5 → no space at all
# ```
#
# So **last valid i = length - 3**
#
# Thus the Python loop must go up to:
#
# ```
# range(len(nums)-2)
# ```
#
# ---
#
# # ✅ **In one sentence**
#
# `len(nums)-2` ensures that after choosing index `i`, there are **still 2 more elements** available to form a triplet.
